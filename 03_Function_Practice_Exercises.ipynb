# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/03_Function_Practice_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WARMUP SECTION:**
#
# LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers if both numbers are even, but returns the greater if one or both numbers are odd
#
#
# lesser_of_two_evens(2,4) --> 2
#
# lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_events(a,b):
  result = ''
  if (a and b) % 2==0:
    return int(a)
    result = a
  else:
    return int(b)
    result = b

# %%
lesser_of_two_events(2,4)
# Out:
# 2

# %%
lesser_of_two_events(2,5)
# Out:
# 5

# %% [markdown]
# ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
#
# animal_crackers('Levelheaded Llama') --> True
#
# animal_crackers('Crazy Kangaroo') --> False

# %%
def animal_crackers(text):
  words = text.split()
  word1 = words[0]
  word2 = words[1]
  if word1[0]==word2[0]:
    return True
  else:
    return False

# %%
animal_crackers('Crazy Kangaroo')
# Out:
# False

# %%
animal_crackers('Levelheaded Llama')
# Out:
# True

# %% [markdown]
# MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 or if one of the integers is 20. If not, return False
#
# makes_twenty(20,10) --> True
#
# makes_twenty(12,8) --> True
#
# makes_twenty(2,3) --> False

# %%
def makes_twenty(n1,n2):
  if n1==20:
    return True
  elif n1+n2 == 20:
    return True
  else:
    return False

# %%
makes_twenty(20,10)
# Out:
# True

# %%
makes_twenty(2,3)
# Out:
# False

# %%
makes_twenty(12,8)
# Out:
# True

# %% [markdown]
# **LEVEL 1 PROBLEMS**
#
#
# OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
#
# old_macdonald('macdonald') --> MacDonald
#
# Note: 'macdonald'.capitalize() returns 'Macdonald'

# %%
def old_macdonald(name):
  list_name = list(name)
  modified_letter1=list_name[0].upper()
  modified_letter2=list_name[3].upper()
  list_name[0]=modified_letter1
  list_name[3]=modified_letter2


  return''.join(list_name)

# %%
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %%
def old_macdonald(name):
  cap = list(name.capitalize())
  cap[3]=cap[3].upper()
  return''.join(cap)

# %%
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def master_yoda(text):
  words=text.split()

  list_text=list(words)
  list_text=list_text[::-1]
  return' '.join(list_text)

# %%
master_yoda('I am home')
# Out:
# 'home am I'

# %%
master_yoda('We are ready')
# Out:
# 'ready are We'

# %%
def master_yoda(text):
  words=text.split()
  words = words[::-1]
  return ' '.join(words)

# %%
master_yoda('We are ready')
# Out:
# 'ready are We'

# %%
list_s=['I','am','home']

# %%
list_s
# Out:
# ['I', 'am', 'home']

# %%
list_s[::-1]
# Out:
# ['home', 'am', 'I']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def almost_there(n):
   target1 = 100
   target2=200
   if abs(target1-n)<=10 or abs(target2-n)<=10:
    return True
   else:
    return False

# %%
almost_there(195)
# Out:
# True

# %% [markdown]
# TEMPERATURE CHECK:
#
#  Given a temperature in Celsius, return True if it's within 5 degrees of the ideal room temperature (22°C) or the ideal sleeping temperature (18°C).

# %%
def temp_check(n):
  return abs(22-n)<=5 or abs(18-n)<=5

# %%
temp_check(23)
# Out:
# True

# %%
temp_check(10)
# Out:
# False

# %% [markdown]
# **LEVEL 2 PROBLEMS**
#
# FIND 33:
#
# Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.
#
#
# has_33([1, 3, 3]) → True
#
# has_33([1, 3, 1, 3]) → False
#
# has_33([3, 1, 3]) → False

# %%
def has_33(nums):
  for i in range(len(nums)-1):
     if nums[i]==3 and nums[i+1]==3:
      return True
  return False

# %%
has_33([1, 3, 3])
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def paper_doll(text):
  result= ' '
  for letter in (text):
    result= result+letter*3

  return result

# %%
paper_doll('Hello')
# Out:
# ' HHHeeellllllooo'

# %%
paper_doll('abcd')
# Out:
# ' aaabbbcccddd'

# %%
paper_doll('Mississippi')
# Out:
# ' MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def blackjack(a,b,c):
 sum = a+b+c
 if sum <=21:
  return sum
 elif 11 in [a,b,c]:
  return sum-10

 else:
  return 'Bust'

# %%
blackjack(5,6,7)
# Out:
# 18

# %%
blackjack(9,9,9)
# Out:
# 'Bust'

# %%
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def summer_69(arr):
  result=0
  add= True

  for num in arr:
    if num == 6:
      add= False
    elif num == 9:
      add= True
    elif add:
      result = result + num

  return result

# %%
summer_69([4, 5, 6, 7, 8, 9])
# Out:
# 9

# %%
summer_69([2, 1, 6, 9, 11])
# Out:
# 14

# %%
summer_69([1, 3, 5])
# Out:
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def spy_game(nums):
  code = [0,0,7]
  for num in nums:
    if num == code[0]:
      code.pop(0)
    if code == [ ]:
      return True
  else:
      return False

# %%
spy_game([1,2,4,0,0,7,5])
# Out:
# True

# %%
 spy_game([1,0,2,4,0,5,7])
# Out:
# True

# %%
spy_game([1,7,2,0,4,5,0])
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def sequence_finder(nums):
  sequence = [1,2,3]
  for num in nums:
    if num == sequence[0]:
      sequence.pop(0)
    if sequence == []:
      return True
  else:
    return False

# %%
sequence_finder([1, 5, 2, 8, 3])
# Out:
# True

# %%
sequence_finder([3, 1, 5, 2, 9])
# Out:
# False
