# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/52_Tuple_Unpacking_with_Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stock_prices=[('APPL',200),('GOOG',300),('MSFT',400)]

# %%
for item in stock_prices:
  print(item)
# Out:
# ('APPL', 200)
# ('GOOG', 300)
# ('MSFT', 400)

# %%
for ticker,price in stock_prices:
  print(ticker)
# Out:
# APPL
# GOOG
# MSFT

# %%
for ticker,price in stock_prices:
  print(price + (price*0.1))
# Out:
# 220.0
# 330.0
# 440.0

# %%
work_hours = [('Abby',100),('Billy',200),('Jenny',900),('Safwan',910)]

# %% [markdown]
# now here we have to do is
#
# we want to see the employee of the year
#
# we will give employee year based on the work_hours.
#
# so we need func that can goes through these tuples and see the names and their work hours and keep a track of their work hours

# %%
def employee_check(work_hours):

  current_max = 0
  employee_of_month = ''

  for employee,hours in work_hours:
    if hours > current_max:
      current_max= hours
      employee_of_month=employee
    else:
      pass
  #Return
  return (employee_of_month,current_max)

# %%
employee_check(work_hours)
# Out:
# ('Safwan', 910)

# %%
result = employee_check(work_hours)

# %%
result
# Out:
# ('Safwan', 910)

# %%
name,hours = employee_check(work_hours)

# %%
name
# Out:
# 'Safwan'

# %%
hours
# Out:
# 910

# %% [markdown]
# 2nd example for practice
#
# Question:
# You have a list of tuples containing student names and their test scores:

# %%
test_scores = [('Alice', 85), ('Bob', 92), ('Charlie', 78), ('Diana', 95), ('Eve', 88),('Steve',99)]

# %%
#Your task: Write a function called top_student(test_scores) that:

#Goes through the tuples
#Finds the student with the highest score
#Returns a tuple with the student's name and their score

# %%
def top_students(test_scores):

  current_highest_score=0
  top_scorer= ''

  for student,marks in test_scores:
    if marks> current_highest_score:
      current_highest_score = marks
      top_scorer = student
    else:
      pass
  #Return
  return (top_scorer,current_highest_score)

# %%
top_students(test_scores)
# Out:
# ('Steve', 99)
