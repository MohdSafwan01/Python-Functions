# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/Methods_and_Functions_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def vol(rad):
  result = (4/3)*3.14*rad**3
  return result

# %%
vol(2)
# Out:
# 33.49333333333333

# %%
vol(3)
# Out:
# 113.03999999999999

# %% [markdown]
# Write a function that checks whether a number is in a given range (inclusive of high and low)
