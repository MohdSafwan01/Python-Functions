# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/def1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def name_of_function():
  print("Hello")

# %%
name_of_function()
# Out:
# Hello

# %%
name_of_function()
# Out:
# Hello

# %%
def name_of_function(name):
  print("Hello "+name)

# %%
name_of_function("safwan")
# Out:
# Hello safwan

# %%
def add_function(num1,num2):
  return num1+num2

# %%
result= add_function(1,2)

# %%
print (result)
# Out:
# 3

# %%
result = add_function(4,7)

# %%
print (result)
# Out:
# 11

# %%
def subtract(num1,num2):
  return num1-num2

# %%
result = subtract(9,5)

# %%
print(result)
# Out:
# 4

# %%
result = subtract(18,9)

# %%
print(result)
# Out:
# 9

# %%
def multiply(num1,num2):
  return num1*num2

# %%
result = multiply(9,5)

# %%
print(result)
# Out:
# 45
