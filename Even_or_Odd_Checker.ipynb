# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/Even_or_Odd_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd():
  number = input('enter a number')
  if int(number)%2==0:
   print('even')
  else:
     print('odd')

# %%
check_even_odd()
# Out:
# enter a number2
# even

# %%
def check_it(check_even_odd):
  if number%2==0:
    print('even')
  else:
    print('odd')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4176375904.py in <cell line: 0>()
# ----> 1 check_it(check_even_odd)
#
# /tmp/ipython-input-2317824926.py in check_it(check_even_odd)
#       1 def check_it(check_even_odd):
# ----> 2   if number%2==0:
#       3     print('even')
#       4   else:
#       5     print('odd')
#
# NameError: name 'number' is not defined
