# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/Even_or_Odd_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd():
  number = input('enter a number')
  if int(number)%2==0:
   print('even')
  else:
     print('odd')

# %%
name, age = input("enter your name"),input('enter ur age')
# Out:
# enter your nameabcd
# enter ur ageacd

# %%
name,age = map(str,input('enter your name and age:').split())
# Out:
# enter your name and age:safwan 21

# %%
"Today is {temp} degrees on {d}".format(temp=90,d='monday')
# Out:
# 'Today is 90 degrees on monday'

# %%
a
