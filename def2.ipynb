# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/def2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def say_hello(name='Default'):
  print(f'hello {name }')

# %%
say_hello()
# Out:
# hello Default

# %%
def say_hello(name):
  return 'hello '+name

# %%
say_hello('Safwan')
# Out:
# 'hello Safwan'

# %%
def print_result(a,b):
  print(a+b)

# %%
print_result(10,20)
# Out:
# 30

# %%
result = print_result(10,20)
# Out:
# 30

# %%
result

# %%
type(reuslt)
# Out:
# NoneType

# %%
def return_result(a,b):
  return a+b

# %%
return_result(10,20)
# Out:
# 30

# %%
result=return_result(10,20)

# %%
result
# Out:
# 30

# %%
def myfunc(a,b):
  print(a+b)
  return a+b

# %%
result= myfunc(10,20)
# Out:
# 30

# %%
result
# Out:
# 30

# %%
def sum_numbers(num1,num2):
  return num1 + num2

# %%
sum_numbers(10,20)
# Out:
# 30

# %%
sum_numbers('10','20')
# Out:
# '1020'
