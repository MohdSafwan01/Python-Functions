# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/Logic_with_Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2%2
# Out:
# 0

# %%
3%2
# Out:
# 1

# %%
41%40
# Out:
# 1

# %%
20%2==0
# Out:
# True

# %%
21%2==0
# Out:
# False

# %%
def even_check(number):
  result = number % 2==0
  return result

# %%
even_check(20)
# Out:
# True

# %%
even_check(21)
# Out:
# False

# %%
def odd_check(number):
  return number%2!=0

# %%
odd_check(20)
# Out:
# False

# %%
odd_check(21)
# Out:
# True

# %%
from ast import Return
def check_even_list(num_list):
  for number in num_list:

    if number % 2 ==0:
      return True
    else:
      pass
  return False

# %%
check_even_list([1,2,3,4])
# Out:
# True

# %%
check_even_list([1,3,5,7])
# Out:
# False

# %%
def check_even_list(num_list):

  even_numbers=[]
  for number in num_list:
    if number % 2 == 0:
      even_numbers.append(number)
    else:
      pass
  return even_numbers

# %%
check_even_list([1,3,5])
# Out:
# []

# %%
check_even_list([1,2,4,5])
# Out:
# [2, 4]

# %%
check_even_list([2,4,5,6])
# Out:
# [2, 4, 6]
