# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Python-Functions/blob/main/skyline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def myfunc(str):
  result=''
  for index,letter in enumerate(str):
    if index % 2==0:
      result = result + letter.upper()
    else:
      result = result + letter.lower()
  return result

# %%
myfunc('abcdef')
# Out:
# 'AbCdEf'
